# %%
docker-compose --version
Docker Compose version 2.31.0
(base) ohhalim@Ohui-MacBookAir ~ % docker info

(base) ohhalim@Ohui-MacBookAir ~ % docker images      
REPOSITORY   TAG             IMAGE ID       CREATED         SIZE
nginx        1.25.3-alpine   f2802c2a9d09   13 months ago   66.4MB
(base) ohhalim@Ohui-MacBookAir ~ %

# %% [markdown]
# 클라우드 저장소의 이미지를 반든경우
# docker pull 192.168.0.101:500/debian:10
# docker pull gcr.io/google-samples/hello-app:1.0
#
#
# 도커 이미지 구조 확인
# docker image inspect nginx:latest
# 도커 이미지 뽑아내기
# docker image inspect --format="{{.Os}}" nginx:latest
#
# 한칸 띄어야함!!
#  docker run -ti --name=ubuntu2204test2 ubuntu:22.04 /bin/bash
#
#
#  cl 지속적 통합
#
#  cd 지속적인 배보
# deployment 배포
#
# 코드를 올리면 배포된다
#
#
#
# 가상화 컨테이너화
#
# 컨테이너 가상화보다 더 가벼운 기술로
#
#
# 이미지 도커 컨테이너 의 템플릿 애플리케이션을 실행할떄 필요한 파이르들 포함한상태
# 컨테이너 이미지 를 기반으로 실행되는 가상환결
#
# 도커 이미지검색 docker search <image _name>
# 도커 허브에
# 이미지로 판다스 파이선 c 뭐 다있음
# 다운하는거 docker pull <image_name>
#
# 도커 이미지 실행 docker run -d -p 80:80 <image_name>
# 터미널에서 부터 때어져라 -d -p 80:80 # 80 에서 80로 연결해라
# 80 = http
# 443 = https
# 22 = SSH
#
# 도커 상테 확인
# docker ps -a
#
# docker gs | grep python # 파이썬의 이미지 상태를 가져와줘
#
# docker stop <container_id> # 컨테이너 중지
# docker rm 삭제
# 이미지삭제는 docker rmi
# 컨테이너 랑 이미지는 따로따로 삭제해야함
#
# docker build -t flask-app .  # t는 태그
# docker run -d -p 5000:5000 flask-app
#
#
# app.py
#
# docker build -t flask-app .
# docker run -d -p 5001:5000 flask-app
# [+] Building 1.8s (9/9) FINISHED                                                       docker:desktop-linux
#  => [internal] load build definition from Dockerfile                                                   0.0s
#  => => transferring dockerfile: 608B                                                                   0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim                                     1.6s
#  => [auth] library/python:pull token for registry-1.docker.io                                          0.0s
#  => [internal] load .dockerignore                                                                      0.0s
#  => => transferring context: 2B                                                                        0.0s
#  => [internal] load build context                                                                      0.0s
#  => => transferring context: 65B                                                                       0.0s
#  => [1/3] FROM docker.io/library/python:3.8-slim@sha256:1d52838af602b4b5a831beb13a0e4d073280665ea7be7  0.0s
#  => => resolve docker.io/library/python:3.8-slim@sha256:1d52838af602b4b5a831beb13a0e4d073280665ea7be7  0.0s
#  => CACHED [2/3] COPY app.py /app.py                                                                   0.0s
#  => CACHED [3/3] RUN pip install Flask                                                                 0.0s
#  => exporting to image                                                                                 0.0s
#  => => exporting layers                                                                                0.0s
#  => => exporting manifest sha256:a49599ab91e9373ae1df3d8e564c28a274e34227760802e7133260b49d6bdd1c      0.0s
#  => => exporting config sha256:745f0ee6b3a7261a6c0d6edde3df02074b668026b7602ea6431e6634850a70ab        0.0s
#  => => exporting attestation manifest sha256:52c79332e88bacc15ac947cf3325a1b7c29de93811a4dea407064745  0.0s
#  => => exporting manifest list sha256:52cba72ec843dad0b9097197e690a0da6bd870209d6c11dfe2a28a1dc7ac349  0.0s
#  => => naming to docker.io/library/flask-app:latest                                                    0.0s
#  => => unpacking to docker.io/library/flask-app:latest                                                 0.0s
# c97012976873407d33ce562bd1d7e1dc49156be624b587c1c5b6518b346638c9
# (base) ohhalim@Ohui-MacBookAir docker %
#
# 이거하고http://localhost:5001/ 웹에 입력하면 뜸
#  Hello, Docker World!

# %% [markdown]
# ![image.png](attachment:image.png)
