# %% [markdown]
# ## 문제 1
# 다음 코드의 출력 결과는 무엇인가요?

# %% [raw]
# # 끝에 쉼표 꼭 붙어야함  ,  요소가 하나뿐인 튜플 선언일때  a  = (1,) # 1개의 요소만 가질때는 뒤에 쉼표를 붙여야함
# # 요소 편집 불가능
#
# tuple_a =(1,2,3,)
# tuple_a[2] = 4 # 편집 불가능
#
# # 리스튼
#
# list_a = [1,2,3]
#
# list_a[2] = 4 # 편집 가능
#
# ##  튜플 사용 ㅋ케이서 > 조작이 되어서느 안되는 케이스
#
# gane_move_range = [1, 0, -1] # 리스트로 만들면 의도치않은 조작이 가능
#
# # 수정되면 위험한 정보는 튜플로 만들기

# %% [raw]
# my_tuple = (1, 2, 3, 4, 5)
# print(my_tuple[2])
# print(my_tuple[4])
# print(my_tuple[6])
#
#
# 3
# 5
# 6번 자리 는 없음

# %%
my_tuple = (1, 2, 3, 4, 5)
print(my_tuple[2])
print(my_tuple[4])
print(my_tuple[6])
# Out:
# 3
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 4
#       2 print(my_tuple[2])
#       3 print(my_tuple[4])
# ----> 4 print(my_tuple[6])
#
# IndexError: tuple index out of range

# %% [markdown]
# ## 문제 2
# 다음 튜플에서 값 4의 인덱스를 구하세요

# %%
my_tuple = (1, 2, 3, 4, 5)

tuple_index = my_tuple.index(4)
print(tuple_index)
# 인덱스 값 찾기

result= my_tuple.index(4)

# 여러게 있을때는 맨처음 발견되는 인덱스만 리턴함
# Out:
# 3

# %% [markdown]
# ## 문제 3
# 다음 튜플에서 요소 3의 개수를 구하세요.

# %%
my_tuple = (1, 3, 3, 3, 5, 3)
# count 메서드에 대해애서 알아봤음
result = my_tuple.count(3)
print(result)
# Out:
# 4

# %% [markdown]
# ## 문제 4
# 다음 코드의 출력 결과는 무엇인가요?

# %% [raw]
# my_tuple = (1, 2, 3, 4, 5)
# print(my_tuple[::-1])
#
# 5?
#
# 아 꺼꾸로 값을 전체 출력하네
# :: 슬라이싱
# my_tuple[:-1] == : 맨첫번째 요소부터 -1 까지출력해

# %%
my_tuple = (1, 2, 3, 4, 5)
print(my_tuple[::-1])
# Out:
# (5, 4, 3, 2, 1)

# %% [markdown]
# ## 문제 5
# 튜플 my_tuple = (10, 20, 30, 40, 50)에서 첫 번째 요소와 마지막 요소를 제외한 중간 요소들로만 이루어진 튜플을 구하세요.

# %%
my_tuple = (10, 20, 30, 40, 50)

print(my_tuple[1:-1]) # 첫번쨰 마지막 제외
# Out:
# (20, 30, 40)

# %%
# 문제 5-1 :: 첫번째 요소 부터 마지막 요소까지 홀수 요소만 출력하세요. 슬라이싱만 써

my_tuple = (10, 20, 30, 40, 50)

print(my_tuple[::2])
# Out:
# (10, 30, 50)

# %%
my_tuple = (10, 20, 30, 40, 50)
슬라이싱 연습 하셈
print(my_tuple[1::2])
# Out:
# (20, 40)

# %% [markdown]
# ## 문제 6
# 다음 코드의 출력 결과는 무엇인가요?

# %% [raw]
# my_tuple = tuple('hello')
# print(my_tuple)

# %%
my_tuple = tuple('hello')
print(my_tuple)
my_tuple = list('hello')
print(my_tuple)
my_tuple = set('hello')
print(my_tuple)
# Out:
# ('h', 'e', 'l', 'l', 'o')
# ['h', 'e', 'l', 'l', 'o']
# {'e', 'l', 'h', 'o'}

# %% [markdown]
# ### 문제 6-1
# 튜플 (1, 2, 3)을 리스트 [1, 2, 3]으로 변환하는 코드를 작성하세요.

# %%
my_tuple = (1, 2, 3)

my_list= list(my_tuple)

print(type(my_list))
# Out:
# <class 'list'>

# %% [markdown]
# ## 문제 7
# 튜플 my_tuple = (1, 2, 3)이 있습니다. 이 튜플에 4를 추가하여 (1, 2, 3, 4)로 만들고 싶습니다. 어떻게 해야 하나요?

# %%
my_tuple = (1, 2, 3)

my_tuple = my_tuple + (4,)
# 불변형이라서 새로운 튜플을 만들어서 할당해야함
my_tuple += (4,)


# 불변형은 덮어씌우는 형식으로 함

# 튜플에 꼭 뒤에 쉼표 붙여야함

# %% [markdown]
# ## 문제 8
# 다음 코드의 출력 결과는 무엇인가요?

# %% [raw]
# a = (1, 2)
# b = (3, 4)
# print(a * 2 + b) #  != 기존의 a b를 수정한것이 아님 /a와 b를 재료로해서 새로운 튜플을 만드는것
# 이어 붙여짐
# (1, 2, 1, 2, 3, 4)

# %% [markdown]
# ## 문제 9
# 다음 코드의 출력 결과는 무엇인가요?

# %% [raw]
# my_tuple = (1, [2, 3], 4)
# my_tuple[1][0] = 'a'
# print(my_tuple)

# %%
my_tuple = (1, [2, 3], 4)
my_tuple[1][0] = 'a'
print(my_tuple)
# 튜플자체는 불변하지만 듀플내에 가변객체는 그 내부는 변경이 가능합니다
# Out:
# (1, ['a', 3], 4)

# %% [markdown]
# ## 문제 10
# 다음 코드의 출력 결과는 무엇인가요?

# %% [raw]
# a = (1, 2)
# b = (3, 4)
# a, b = b, a
# print(a)
# print(b)

# %% [raw]
# my_tuple = (1, 2, 3)
# x, y, z = my_tuple # 언팩킹
# print(x, y, z) 숫자를 맞추어서 넣어야함

# %% [raw]
# def func():
#     return 1, 2, 3
#
# result = func()
# print(type(result))

# %%
def func():
    return 1, 2, 3 # 함수가 여러값을 반환하면 튜플로 묶어서 반환
    

result = func()
print(type(result))

# %% [markdown]
# ## 문제 11
# 다음 튜플에서 최대값과 최소값을 구하세요.

# %%
numbers = (5, 2, 8, 1, 3)

# %%
 numbers = (5, 2, 8, 1, 3)
my_tuple = numbers


print(max(numbers))
print(min(numbers))
# Out:
# 8
# 1

# %% [markdown]
# ## 문제 12
# 튜플 (1, 2, 3, 4, 5)를 문자열 '1 2 3 4 5'로 변환하는 코드를 작성하세요.

# %%
# 튜플 (1, 2, 3, 4, 5)를 문자열 '1 2 3 4 5'로 변환하는 코드를 작성하세요.
tuple = (1, 2, 3, 4, 5)

tuple = ' '.join(map(str, tuple))
# john
print(type(tuple))
#  조인 구분자를 중간중간 넣어서 합쳐진 문자열 
# 맵함수 반
# Out:
# <class 'str'>

# %% [markdown]
# ![image.png](attachment:image.png)
