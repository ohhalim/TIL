# %% [markdown]
# 241219 오늘한거
#
# 장고 강의: 기초 1-15강 부터 ?? > 정리위치: django폴더
#
# 베이직반 강의: 함수배운다 ?? > 정리위치: ???
#
# api 특강: 문서화특강 > 솔직히 뭔말인지 모르겠다 내가 진도가 안나가서 심화에 내용 있던데 그것까지 확인하면 무슨 말인지 알겠지 > 정리위치: 여기
#
# 개인과제 : 이거 어떻게 시작하지..> 먼저 그냥 막 해보자 > 먼저 기초장고 강의 15강 까지 배운내용 과제폴더에다가 만들어 둠 > 정리위치: assignment 폴더
#
# 추가 과제
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## tree 명령어로 내부 구조 알수있음 터미널에서
# ```
# my_pjt/
# ├── manage.py
# └── my_pjt/
#     ├── __init__.py
#     ├── asgi.py
#     ├── settings.py
#     ├── urls.py
#     └── wsgi.py
#
# ```

# %% [markdown]
# # api 특강
# ![image.png](attachment:image.png)
#
# 백엔드 가실분들은 꼭알아야함
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 문서화 : 백엔드가 만든 api를 프론트엔드가 알기 쉽게 만드는것
