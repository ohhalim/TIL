# %% [markdown]
# 오늘할거
# 팀 과제  챗봇을 필수과제에서 요구하는 성능 추가 업데이트 완료
# ```
# 주말인데 평일과 같이 일어나서 9시에 도서관왔다
# 계속 똑같은 루틴을 반복하는게 효율적으로 집중이 된다.
# 몸이 기억하는 것 같다. 언제 집중하고 언제 밥먹는지.
# 그래서 편안하다.
# ```
# 일단 독해 먼저 하려고 한다
# 독해 했고 앱 실행했음
#
# 지금 전 채팅 기억을 못함 이거 기억하게 만들고
#
#
#
# - [ 이거 지금 함]  사용자와의 대화 내역을 저장하고 관리합니다.
#
# - **대화 세션 관리**
#     - [ ?? 이것도 해야하는데]  각 대화 세션을 구분하여 저장하고, 불러올 수 있습니다.
#     나중에 해
#
#
# - **RAG 관련 내용**
#     - [ ]  FAISS를 Retriever로 변환할 수 있습니다.
#     - []  모델과 프롬프트를 연결하는 RAG 체인을 구성할 수 있습니다.
#
#
#
#
# 챗봇이 rag 가 아님
#
# 그냥 api임
#
#
# 데이터랑 연결시켜야함
# today_news.json
# 데이터랑 연결시켜야하고
#
# 연결시키는 방법은 랭체인 이어야해
#
# 세부방법은 파이스 리트리버를 사용
#
# 챗봇만 완성하면 되나??
#
#
# 챗봇만 완성한다고 하면
# 최우선으로 끝내야할게 뭐야
#
# 1. 랭체인
#
# # 그럼 이제 랭체인 파이스 리트리버 만 하면돼
#
#
# 2. 대화저장 이거 했어
