# %% [markdown]
# # 241230 오늘 한거
# 장고 심화 못 들은거 들음
# 모든건 공식문서 보고 배우고 써먹는거구나
# 공식문서에 다 나와있구나
# 파이썬도 랭체인도 장고도 트랜스포머도
#
#
# ai 로 작성했는지 프로그램으로 체크함 그러니까 내 말로 바꿔서 사용하셈
#
# 지라, 도커, aws 서버연결, 깃허브 CI CD, 장고DRF, LLM RAG, SA문서, ERD, API명세서, README, 프론트는 특강에서 보여준 거로 사용, 실사용 유저테스트
#
# sa 문서 , 팀노션 만듬

# %% [markdown]
# ## 리더 부리더 특강
#
# 취업을 위한 포트폴리오
#
#
# 일방적으로 코드 고치치 말기
#
# 팀원이 담당한 기능 일방적으로 뺏지 말기
#
# 분위기 메이커 되어야함
# 잘 경청하고 소통하기
#
# 그라운드 룰을 지키는 팀이 되자
