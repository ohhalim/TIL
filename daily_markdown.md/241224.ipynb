# %% [markdown]
# 241224 오늘 한 거
# ------
# 개인과제1 장고:
# 프로필까지 > 정리위치: 스파르타마켓폴더 < 가장 중요한 일
# erd
# read me
# ----------
# 개인과제2 장고 drf:
# ???? > 정리위치:  < 가장 중요한 일
# erd
# read me
# -------
# 도커 특강 : 5시에 배웠음  > 저장위치: 여기
#
# drf 특강 : 2시에 배웠음   > 저장위치: 여기랑 교육자료에 스켈레톤 폴더 봐
#
# 베이직반 수업: 예외처리 배움 > 저장위치: 코드카타

# %% [markdown]
# # drf 강의

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 하려면 로그인해야돼
# 그러려면
# ![image.png](attachment:image.png)

# %% [markdown]
# 탭하나 더 까서![image.png](attachment:image.png)

# %% [markdown]
# 이렇게 기존에 있있던 정보들을 가져와서 넣ㅗ
# access 토큰을 얻어
# 그래고 토큰값에 넣어 ![image.png](attachment:image.png)

# %% [markdown]
# 그럼 됨

# %% [markdown]
# # 도커강의
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# name: Deploy to cloudtype
# on:
#   push:
#     branches:
#       - main
# jobs:
#   deploy:
#     runs-on: ubuntu-latest
#     steps:
#       - name: Checkout
#         uses: actions/checkout@v2
#       - name: Connect deploy key
#         uses: cloudtype-github-actions/connect@v1
#         with:
#           token: ${{ secrets.CLOUDTYPE_TOKEN }}
#           ghtoken: ${{ secrets.GHP_TOKEN }}
#       - name: Deploy
#         uses: cloudtype-github-actions/deploy@v1
#         with:
#           token: ${{ secrets.CLOUDTYPE_TOKEN }}
#           project: ohhalim777/sparta-coding-product
#           stage: main
#           yaml: |
#             name: sparta-coding-product
#             app: python@3.9
#             options:
#               env:
#                 - name: DJANGO_SECRET
#                   value: 5xeuu%71e@wu=#f@^xs6fp0d$adc@c7dvk@8-gfb%0r@ynpe*-
#               ports: 8000
#               start: python3 manage.py runserver 0:8000
#               buildenv: []
#             context:
#               git:
#                 url: git@github.com:${{ github.repository }}.git
#                 ref: ${{ github.ref }}
#               preset: python-django
