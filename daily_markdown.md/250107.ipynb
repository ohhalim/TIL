# %% [markdown]
# 프론트 도커 되는거 어제 확인함 .
#
# 이제 로컬에서 작업하고 나중에 프론트 도커에 올릴거
#
# 일기 데이터 하는거
#
# 백에서는 되는거 확인하고
# 프론트에 문제있는거 확인
# 그래서 프론트 고치고 일기 데이터 저장되게 바꿈
#
# todo 일정 ui 추가 아래 사진있음
#
# 프론트 폴더에 예전  ai rag 프젝 파일 가져와 넣었다(테스트).→ 일기 내용을 입력으로 ai 챗봇 출력해봄  됨  →
# 사진
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
#
# 도커에서 작업하기가 어려윰
#
# 리액트를 도커에 올릴지
#
# 로컬에서 작업하고 나중에 합칠지
#
# 되는건 확인함
# -----
#
# 무아 튜터님 말씀!
# 로컬에서 작업하고 나중에 합쳐도 된다!
#
#
#
#
# 계속 개발일 하면서 나중에 도커 익숙해지면 하면 그떄 그렇게 해도 된다
#
#
#
#
#
# 기능 테스트 엑시오스로 전달하는것만 확인해라
#
#
# 백 건들지 마라!
# 없는기능 공유만
#
# 문서로만 의사소통해라
#
#
# api 문서 담당자 정해서
#
#
# 일자별로 뭐할건지 나누는거 해야함!
#
#
# 기초적인 핵심적인 것만 만들고
#
#
# 그 다음에 더 나누기
#
#
# 프론트
# api 명세서에서 구현된 것만 엑시오스로 테스트
#
# 디자인 것만 신경쓰고 나중에

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
