# %% [markdown]
# 241212 오늘한거
#
# 장고강의: 하고있음 > ???  : 정리위치 : > ???
#
# 수준별학습반: 이거 오늘 다 뿌실거임  : 정리위치 : > 코드 카타 파일 <<<< 오늘 가장 중요한거
#
# -
#     이거 오늘 다 뿌시자.
#
#     강의자료 다보고
#
#     동영상 보면서 같이 문제 푸는거 이게 오늘 최우선 과제
#
#     오늘 한거 문제 풀이에 적어 두었음
#
#
#
# 도커: 하고있음 > ???  : 정리위치 : > ???
#
# 개인과제: 하고있음 > ???  : 정리위치 : > ???
#
# ERD 특강: 들었음 : 정리위치 : > 이 파일

# %% [markdown]
# # ERD 특강
#
# 개체 개체간의 관계 그리고 개체의 속성을 시각적으로 표현한 다이어 그램
#
#
#
# 비즈니스의 요구상항의 체계적 이해
# 비개발자와 원할한 커뮤니케이션
#
# 데이터 구조 시각화
#
#
# **정규화와 무결성 확보**
#
# 데이터 정규화를 진행 데이터 중복과 이상 현상을 방지
#
#
# 데이터 베이스를 설계하기 전단계

# %% [markdown]
# 개체 entity
# db에서 독립저긍로 관리할 가치가 있는 대상
# OR 업무에서 관리하고자 하는 실체
#
# 실제로 존재하거나 관리 대상인 명사
# 개체란 자세한 정보를 담은 상자
#
# 속성 attribute
# 기본키 : 식별할수있는것
#
# 관계 relationship
# 고객이 주문을 한다 : 관계
#
# ERD 관계
# 사각형 :개채
# 동그라미: 속성
# 마름모 :관계
#
# ![image.png](attachment:image.png)
#
# 노란색으로 되어있는 글자가 개체
# 선들은 관계

# %% [markdown]
# 직사각형 제일 위해 표시
# 개체명을 명확하고 단수형을 ㅗ작성하는것이 일반적
#
#
# 관계 연결하는 선으로 표현
# 동사구로도 표현
#
# ----------------------
# ![image.png](attachment:image.png)
# 관계 표현 방법

# %% [markdown]
# -------------------
# ![image.png](attachment:image.png)
# 예제

# %% [markdown]
# ---------------
# ![image.png](attachment:image.png)
# 다 대 다 관계일떄는 매개체가 필요할수도 있음

# %% [markdown]
# ------------------------
# ![image.png](attachment:image.png)
#
#
# ----------------------

# %% [markdown]
# 실습
#
# https://app.diagrams.net/
#
# 서비스: 간단한 온라인 도서 마켓
#
#  - 개체와 속성을 먼저 생각하고 작성
#  user :
#   id(pk)
#   password
#   age
#   username
#
# book :
#   id
#   author
#   price
#   stock
#   published_date
#   publisher
#   Category_id (fk)
#
# book category :
#  id(PK)
#  name
#
# order :
#  user_id (fk)
#  order_Date
#  total_price
#
#
# orderitem :
#  id(pk)
#  book_id(fk)
#  order_id(FK)
#  quantity
#  price
#
# review :
#  id(pk)
#  user_id(fk)
#  book_id(fk)
#  rating
#  comment
#  created_at

# %% [markdown]
# 각 개체간의 관계 생각하고 작성
# user 와  order 는 1:n 관계
#
# order 와 orderitem은 1:n
#
# book 과 orderitem 은 1:n
#
# book 과 category n:m or n:1
#
# user와 review 1:n
#
# book 과 review 1:n

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# 이렇게 만들어 봤음
