# %% [markdown]
# # 1-16 django form
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 유저가 입력한 데이터가 유효한지 검사가 필요하다
#
# 중복되는 코드를 줄일수있는 django form을 제공
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)![image.png](attachment:image.png)

# %% [markdown]
# 모델 폼 해보자
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# model form에서 알아서 해줌
#
# ![image.png](attachment:image.png)

# %% [markdown]
# form = ArticleForm(request.POST)  # POST 데이터가 폼에 바인딩됨
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# new - create 수정
