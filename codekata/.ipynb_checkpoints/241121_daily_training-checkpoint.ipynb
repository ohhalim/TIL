# %% [markdown]
# ![스크린샷 2024-11-21 오후 5.07.20.png](attachment:8afa7b3c-f449-4123-80ff-3e26e8056723.png)![스크린샷 2024-11-21 오후 5.47.56.png](attachment:880eb4a8-53c3-4bef-8ad8-84bd2c123e17.png)

# %%
a =input()
print(f"A is {a}")
# Out:
#  hello
# A is hello

# %%
a = input()

print(f"a is {a}")
# Out:
#  2
# a is 2

# %%
n = input()
print(f"your score is {n}point")
# Out:
#  e
# your score is epoint

# %%
n = input()
print(f"Your score is {n} point.")

# %% [markdown]
# ![스크린샷 2024-11-21 오후 5.56.49.png](attachment:f1f72161-181f-49f8-9f12-bc1e8c6a9edf.png)

# %%
a = int(input())

print(a*2+3)

# %% [markdown]
# ![스크린샷 2024-11-21 오후 6.08.55.png](attachment:ae5a540c-d2f5-463c-986f-993c7b5ac059.png)![스크린샷 2024-11-21 오후 6.09.08.png](attachment:95bb60fb-6f28-4a1b-9fe5-e28aa438fd0d.png)

# %% [markdown]
# ![스크린샷 2024-11-21 오후 6.09.25.png](attachment:de7334a7-e4f5-47bb-8fab-9ecf11a714f5.png)

# %% [markdown]
# ![스크린샷 2024-11-21 오후 6.11.58.png](attachment:fe1d4ada-9382-41d6-9ffa-60ce0a59e3e6.png)![스크린샷 2024-11-21 오후 6.12.08.png](attachment:ed717ee3-f3af-4e37-84e5-d5b1644d2faa.png)

# %% [markdown]
# ![스크린샷 2024-11-21 오후 7.57.12.png](attachment:04231b44-c79b-4b86-8f94-fe6e557a0528.png)![스크린샷 2024-11-21 오후 8.14.54.png](attachment:765da6ea-2fde-4f16-b7c7-07a13ad4321e.png)
#
# 이렇게 해서 틀림
# 재밌기는 하다
