# %% [markdown]
# LLM의 사용 준비하기![스크린샷 2024-11-08 오후 5.39.17.png](attachment:3999462a-558d-4421-bdbc-ebb3559c48eb.png)![스크린샷 2024-11-08 오후 5.39.25.png](attachment:eaad9938-a2b4-4fb6-b03d-61f143241b27.png)![스크린샷 2024-11-08 오후 5.39.35.png](attachment:ff458540-b29c-47c3-958b-3ed6cef4e519.png)![스크린샷 2024-11-08 오후 5.39.44.png](attachment:ee736ec8-4805-47bb-bd98-f39eb9c38517.png)![스크린샷 2024-11-08 오후 5.39.52.png](attachment:018f8020-894c-4382-ae6f-f600cb1bbc06.png)![스크린샷 2024-11-08 오후 5.40.02.png](attachment:2297f630-5923-401d-8d1d-4a6712878766.png)![스크린샷 2024-11-08 오후 5.40.10.png](attachment:68983f6e-b064-4305-b4ca-cae219c98aac.png)

# %% [markdown]
# llm 은 데이터의 보안에 반드시 신경써야한다
# 1. 데이터를 처리하기전에 자동으로 걸러내는 필터링 시스템을 구축
# 2. 암호화, 데이터는 저장 전송중에 암호화되어야한다
# 3. 데이터 저장 최소화, rag 랑과 관련이 있음
# 4. 접근 통제 , 데이터에 접근하지 못하게 하는것도 방법
#
# api 란 서로 다른 소프트웨어가 데이터와 기능을 주고 받을수 잇도 록하느 인터페이스
#
#
# 대부분의 api 는 http 로 요청과 응답이 이루어진다
#
# restfil api  가장 흔히 사용되는 셜계방식
