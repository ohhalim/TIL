# %% [markdown]
# ![스크린샷 2024-11-08 오후 5.54.26.png](attachment:ccb30c41-08df-4704-a224-f03f9faa3f54.png)![스크린샷 2024-11-08 오후 5.54.40.png](attachment:28e79e73-fc13-4012-95a1-e6882edbd626.png)![스크린샷 2024-11-08 오후 5.54.46.png](attachment:744cef1b-73f9-491d-be71-5e65ad4c80c2.png)![스크린샷 2024-11-08 오후 5.54.55.png](attachment:f0ba5c9b-4eb0-46ac-923b-011e96eaee5d.png)![스크린샷 2024-11-08 오후 5.55.01.png](attachment:e50d6038-7ce0-439c-93c2-d81b8570315c.png)![스크린샷 2024-11-08 오후 5.55.09.png](attachment:31b4541e-8c10-441c-8d23-95684b80f913.png)![스크린샷 2024-11-08 오후 5.55.31.png](attachment:64965743-555e-4481-96fd-2ccbc3c01c04.png)![스크린샷 2024-11-08 오후 5.55.37.png](attachment:c1f0d461-3551-46be-ac34-0d7e94c906f2.png)

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Multilingual-E5-large-instruct 모델 로드
model = SentenceTransformer('intfloat/multilingual-e5-large')

# 문장 리스트
sentences = [
    "참새는 짹짹하고 웁니다.",
    "LangChain과 Faiss를 활용한 예시입니다.",
    "자연어 처리를 위한 임베딩 모델 사용법을 배워봅시다.",
    "유사한 문장을 검색하는 방법을 살펴보겠습니다.",
    "강좌를 수강하시는 수강생 여러분 감사합니다!"
]

# 문장들을 임베딩으로 변환
embeddings = model.encode(sentences)

# 임베딩 벡터 출력
print(embeddings.shape)  # (4, 1024) - 4개의 문장이 1024 차원의 벡터로 변환됨
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 import numpy as np
#       4 # Multilingual-E5-large-instruct 모델 로드
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
# !pip install sentence-transformers
# Out:
# ...
#   Using cached sentence_transformers-3.2.1-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
# ...

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Multilingual-E5-large-instruct 모델 로드
model = SentenceTransformer('intfloat/multilingual-e5-large')

# 문장 리스트
sentences = [
    "참새는 짹짹하고 웁니다.",
    "LangChain과 Faiss를 활용한 예시입니다.",
    "자연어 처리를 위한 임베딩 모델 사용법을 배워봅시다.",
    "유사한 문장을 검색하는 방법을 살펴보겠습니다.",
    "강좌를 수강하시는 수강생 여러분 감사합니다!"
]

# 문장들을 임베딩으로 변환
embeddings = model.encode(sentences)

# 임베딩 벡터 출력
print(embeddings.shape)  (5, 1024)# (4, 1024) - 4개의 문장이 1024 차원의 벡터로 변환됨
print(embeddings[0])
# Out:
# (5, 1024)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 20
#      17 embeddings = model.encode(sentences)
#      19 # 임베딩 벡터 출력
# ---> 20 print(embeddings.shape)  (5, 1024)# (4, 1024) - 4개의 문장이 1024 차원의 벡터로 변환됨
#      21 print(embeddings[0])
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# 분포가설??
