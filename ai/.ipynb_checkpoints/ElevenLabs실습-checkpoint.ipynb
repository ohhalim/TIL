# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install elevenlabs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install ffmpeg
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - pytorch
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/ai
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.16.0               |       h302bd0f_5         1.0 MB
#     ffmpeg-6.1.1               |       h4beb5bb_0         9.0 MB
#     fontconfig-2.14.1          |       hee714a5_2         254 KB
#     fribidi-1.0.10             |       h1a28f6b_0          60 KB
#     gdk-pixbuf-2.42.10         |       h80987f9_1         579 KB
#     graphite2-1.3.14           |       hc377ac9_1          75 KB
#     harfbuzz-4.3.0             |       he9eebac_2         1.1 MB
#     lame-3.100                 |       h1a28f6b_0         312 KB
# ...

# %%
import os
import requests
from pydub import AudioSegment
from pydub.playback import play
import io
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("ELEVENLABS_API_KEY")

url = "https://api.elevenlabs.io/v1/text-to-speech/21m00Tcm4TlvDq8ikWAM"  # 기본 음성 ID

# 설정 가능한 변수
output_filename = "output_audio.mp3"

url = "모델 URL"
headers = {
    "xi-api-key":  api_key,
    "Content-Type": "application/json"
}

# 문장을 입력받습니다.
text = input("텍스트를 입력하세요: ")

# 음성 생성 요청을 보냅니다.
data = {
    "text": text,
    "model_id": "eleven_multilingual_v2",
    "voice_settings": {
        "stability": 0.3,
        "similarity_boost": 1,
        "style": 1,
        "use_speaker_boost": True
    }
}

response = requests.post(url, json=data, headers=headers, stream=True)

if response.status_code == 200:
    audio_content = b""
    for chunk in response.iter_content(chunk_size=1024):
        if chunk:
            audio_content += chunk

    segment = AudioSegment.from_mp3(io.BytesIO(audio_content))
    segment.export(output_filename, format="mp3")
    print(f"Success! Wrote audio to {output_filename}")

    # 오디오를 재생합니다.
    play(segment)
else:
    print(f"Failed to save file: {response.status_code}")
# Out:
# 텍스트를 입력하세요:  hi
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/util/url.py:440, in parse_url(url)
#     438     port_int = None
# --> 440 host = _normalize_host(host, scheme)
#     442 if normalize_uri and path:
#
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/util/url.py:326, in _normalize_host(host, scheme)
#     324         elif not _IPV4_RE.match(host):
#     325             return to_str(
# --> 326                 b".".join([_idna_encode(label) for label in host.split(".")]),
#     327                 "ascii",
#     328             )
#     329 return host
#
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/util/url.py:344, in _idna_encode(name)
#     343     except idna.IDNAError:
# --> 344         raise LocationParseError(
# ...

# %%
import os
import requests
from pydub import AudioSegment
from pydub.playback import play
import io
from dotenv import load_dotenv

# 환경 변수 로드
load_dotenv()

# API 키 가져오기
api_key = os.getenv("ELEVENLABS_API_KEY")

# Eleven Labs API URL - 실제 URL을 사용합니다.
url = "https://api.elevenlabs.io/v1/text-to-speech/21m00Tcm4TlvDq8ikWAM"  # 기본 음성 ID

# 파일 이름 설정
output_filename = "output_audio.mp3"

# 헤더 설정
headers = {
    "xi-api-key": api_key,
    "Content-Type": "application/json"
}

# 텍스트 입력
text = input("텍스트를 입력하세요: ")

# 음성 생성 요청 데이터
data = {
    "text": text,
    "model_id": "eleven_multilingual_v2",
    "voice_settings": {
        "stability": 0.3,
        "similarity_boost": 1,
        "style": 1,
        "use_speaker_boost": True
    }
}

# POST 요청 보내기
response = requests.post(url, json=data, headers=headers, stream=True)

# 응답 처리
if response.status_code == 200:
    audio_content = b""
    for chunk in response.iter_content(chunk_size=1024):
        if chunk:
            audio_content += chunk

    # MP3 파일로 저장
    segment = AudioSegment.from_mp3(io.BytesIO(audio_content))
    segment.export(output_filename, format="mp3")
    print(f"Success! Wrote audio to {output_filename}")

    # 오디오 재생
    play(segment)
else:
    print(f"Failed to save file: {response.status_code}")
# Out:
# 텍스트를 입력하세요:  안녕
# Failed to save file: 401
